# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
import pandas as pd
import numpy as np
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-68cbd68f-df4b-4a63-9fa6-08c7c098b1a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68cbd68f-df4b-4a63-9fa6-08c7c098b1a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CarPrice_Assignment.csv to CarPrice_Assignment.csv

# %%
import tensorflow as tf
df = pd.read_csv(io.BytesIO(uploaded['CarPrice_Assignment.csv']))

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2                audi 100ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
df['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100ls', 'audi fox', 'audi 5000',
#        'audi 4000', 'audi 5000s (diesel)', 'bmw 320i', 'bmw x1', 'bmw x3',
#        'bmw z4', 'bmw x4', 'bmw x5', 'chevrolet impala',
#        'chevrolet monte carlo', 'chevrolet vega 2300', 'dodge rampage',
#        'dodge challenger se', 'dodge d200', 'dodge monaco (sw)',
#        'dodge colt hardtop', 'dodge colt (sw)', 'dodge coronet custom',
#        'dodge dart custom', 'dodge coronet custom (sw)', 'honda civic',
#        'honda civic cvcc', 'honda accord cvcc', 'honda accord lx',
#        'honda civic 1500 gl', 'honda accord', 'honda civic 1300',
#        'honda prelude', 'honda civic (auto)', 'isuzu MU-X',
#        'isuzu D-Max ', 'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf',
#        'jaguar xk', 'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe',
#        'mazda rx-4', 'mazda glc deluxe', 'mazda 626', 'mazda glc',
#        'mazda rx-7 gs', 'mazda glc 4', 'mazda glc custom l',
#        'mazda glc custom', 'buick electra 225 custom',
#        'buick century luxus (sw)', 'buick century', 'buick skyhawk',
#        'buick opel isuzu deluxe', 'buick skylark',
#        'buick century special', 'buick regal sport coupe (turbo)',
#        'mercury cougar', 'mitsubishi mirage', 'mitsubishi lancer',
#        'mitsubishi outlander', 'mitsubishi g4', 'mitsubishi mirage g4',
#        'mitsubishi montero', 'mitsubishi pajero', 'Nissan versa',
#        'nissan gt-r', 'nissan rogue', 'nissan latio', 'nissan titan',
#        'nissan leaf', 'nissan juke', 'nissan note', 'nissan clipper',
#        'nissan nv200', 'nissan dayz', 'nissan fuga', 'nissan otti',
#        'nissan teana', 'nissan kicks', 'peugeot 504', 'peugeot 304',
#        'peugeot 504 (sw)', 'peugeot 604sl', 'peugeot 505s turbo diesel',
#        'plymouth fury iii', 'plymouth cricket',
#        'plymouth satellite custom (sw)', 'plymouth fury gran sedan',
#        'plymouth valiant', 'plymouth duster', 'porsche macan',
#        'porcshce panamera', 'porsche cayenne', 'porsche boxter',
#        'renault 12tl', 'renault 5 gtl', 'saab 99e', 'saab 99le',
#        'saab 99gle', 'subaru', 'subaru dl', 'subaru brz', 'subaru baja',
#        'subaru r1', 'subaru r2', 'subaru trezia', 'subaru tribeca',
#        'toyota corona mark ii', 'toyota corona', 'toyota corolla 1200',
#        'toyota corona hardtop', 'toyota corolla 1600 (sw)',
#        'toyota carina', 'toyota mark ii', 'toyota corolla',
#        'toyota corolla liftback', 'toyota celica gt liftback',
#        'toyota corolla tercel', 'toyota corona liftback',
#        'toyota starlet', 'toyota tercel', 'toyota cressida',
#        'toyota celica gt', 'toyouta tercel', 'vokswagen rabbit',
#        'volkswagen 1131 deluxe sedan', 'volkswagen model 111',
#        'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
#check if there are empty cells, if there are then row and column indexes will be returned where values are empty or missing
np.where(df.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
# correct the name error in audi 100 ls
df.iloc[3,2] = 'audi 100ls'

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df.drop(columns=['car_ID'], inplace = True)

# %%
# get columns so that we can use the column names for onehot encoding of catagorical featrues in next cell
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
# onehot encode all catagorical columns
final_car = pd.get_dummies(df, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
#checking statistical data to see abnormal values and outliers
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
#initialize a seed value so that each time we can get the same random number sequence
# 0.72 means we have taken 72% values for training set as we will make 72/4 = 18 rows of k fold validation data
# value of k will be 4 when we compile and fit our model for validation
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
#check the length of our test and train datasets
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
# check statistical overview if there are some outliers and abnormal values
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
# storing price in another dataframe
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
# droping price from original dataset , as model have to predict price
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 192)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
#get indices of the columns so that we can know how many columns we have to normalize, as catagorical columns which we
# have added with onehot encoding, do not need to be normalized.. normalizing will be done in next cell
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
# normalization is carried out because that data has large vlaues in decimal and it will effect the performance of our model
# may overfit or we may face hardware resource high usage
# we will apply the formula normalized_train_data = (train_data - mean)/ stadrad_deviation
# firt find mean and std of training data, then subtract mean from each value of the array slice train_data.iloc[:,0:13]
mean = train_data.iloc[:,0:13].mean(axis=0) # taking the mean of 
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
mean_label
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 192)

# %%
#store in numpy array
test = np.array(test_data.iloc[:]).astype('float32')
train = np.array(train_data.iloc[:]).astype('float32')
test_l= np.array(test_label.astype('float32'))
train_l= np.array(train_label.astype('float32'))

# %%
train.shape[1]
# Out:
# 192

# %%
(141,192)[1]
# Out:
# 192

# %%
train.dtype
# Out:
# dtype('float32')

# %%
#Models section
# WE will configure different models here according to relu, tanh , regularization, dropout etc..
# we are passing activation function as a parameter here so that we can call this function with tanh or relu while
# fitting and training the model
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                1930
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# K Fold validation section
# here we will use len(train)//k to make 141//4 = 36 rows for validation in each validation test and collect the validation scores for relu , tanh , regularization , and dropout
# k fold validation with relu
# 141/4
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
# 141/4
#k fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f478691d3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f478574ef80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4785f96560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f47879a0050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f478c5a6b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f478568c290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f478568c050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f478568cd40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.9033 - mae: 0.7077
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0704 - mae: 0.7188
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8541 - mae: 0.5856
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6951 - mae: 0.5411
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7239 - mae: 0.5681
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6514 - mae: 0.5391
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3799 - mae: 0.4315
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5646 - mae: 0.5011
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4910 - mae: 0.4515
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5146 - mae: 0.4588
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3278 - mae: 0.3953
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3917 - mae: 0.4228
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7294 - mae: 0.5393
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3860 - mae: 0.4358
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2353 - mae: 0.3483
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4648 - mae: 0.4382
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2376 - mae: 0.3642
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2334 - mae: 0.3541
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3881 - mae: 0.4271
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2474 - mae: 0.3690
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2269 - mae: 0.3501
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1576 - mae: 0.2856
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2349 - mae: 0.3440
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2881 - mae: 0.3698
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3236 - mae: 0.4003
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2231 - mae: 0.3281
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2728 - mae: 0.3478
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2769 - mae: 0.3935
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3789 - mae: 0.3740
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2443 - mae: 0.3421
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3243 - mae: 0.3670
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3374 - mae: 0.3351
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2925 - mae: 0.3601
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2913 - mae: 0.3681
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1174 - mae: 0.2449
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2139 - mae: 0.2877
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5374 - mae: 0.4265
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3200 - mae: 0.3318
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7713 - mae: 0.4574
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1293 - mae: 0.2685
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3054 - mae: 0.3729
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2010 - mae: 0.3400
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1800 - mae: 0.2994
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1822 - mae: 0.2844
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3281 - mae: 0.3608
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2861 - mae: 0.3181
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2426 - mae: 0.3052
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2881 - mae: 0.3010
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1969 - mae: 0.3140
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1245 - mae: 0.2437
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1446 - mae: 0.2771
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3709 - mae: 0.3900
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5769 - mae: 0.4467
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4294 - mae: 0.3710
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1339 - mae: 0.2279
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2149 - mae: 0.3083
# Epoch 57/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1616 - mae: 0.2541
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2840 - mae: 0.3052
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3613 - mae: 0.3457
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3952 - mae: 0.3653
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1433 - mae: 0.2746
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1218 - mae: 0.2551
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1956 - mae: 0.2724
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1661 - mae: 0.2546
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1681 - mae: 0.2915
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2465 - mae: 0.3200
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2605 - mae: 0.3326
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2297 - mae: 0.2654
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0985 - mae: 0.2202
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2121 - mae: 0.2903
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4049 - mae: 0.3276
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3629 - mae: 0.3353
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1617 - mae: 0.2431
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4471 - mae: 0.3523
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1900 - mae: 0.2891
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4389 - mae: 0.3785
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1537 - mae: 0.2513
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1315 - mae: 0.2606
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1576 - mae: 0.2400
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1563 - mae: 0.2372
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1714 - mae: 0.2757
# Epoch 82/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4087 - mae: 0.3766
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1914 - mae: 0.2767
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3531 - mae: 0.3504
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1371 - mae: 0.2294
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1445 - mae: 0.2356
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1015 - mae: 0.2242
# Epoch 88/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1906 - mae: 0.2845
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1402 - mae: 0.2597
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2152 - mae: 0.2676
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2117 - mae: 0.2674
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1606 - mae: 0.2318
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1812 - mae: 0.2623
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2794 - mae: 0.3204
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1281 - mae: 0.2466
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2971 - mae: 0.3287
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3751 - mae: 0.3200
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1189 - mae: 0.2420
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2465 - mae: 0.2990
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2195 - mae: 0.2744
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f478771d440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4331 - mae: 0.4502
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.0461 - mae: 0.7775
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7946 - mae: 0.6874
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3499 - mae: 0.4042
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3867 - mae: 0.4408
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3719 - mae: 0.4408
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2753 - mae: 0.3908
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2580 - mae: 0.3703
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2858 - mae: 0.3665
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2813 - mae: 0.3674
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2494 - mae: 0.3403
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2643 - mae: 0.3338
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2887 - mae: 0.3757
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2123 - mae: 0.3531
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2650 - mae: 0.3466
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2324 - mae: 0.3024
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3006 - mae: 0.3730
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3555 - mae: 0.3506
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2217 - mae: 0.3273
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1297 - mae: 0.2532
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1883 - mae: 0.3015
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1734 - mae: 0.2913
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4716 - mae: 0.4004
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2487 - mae: 0.3281
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1671 - mae: 0.2947
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3161 - mae: 0.3719
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1114 - mae: 0.2439
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7167 - mae: 0.4704
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1895 - mae: 0.2999
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2687 - mae: 0.3377
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2707 - mae: 0.3016
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3785 - mae: 0.3568
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2301 - mae: 0.3118
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1034 - mae: 0.2378
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1404 - mae: 0.2777
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1823 - mae: 0.2900
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1463 - mae: 0.2602
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1320 - mae: 0.2733
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1647 - mae: 0.2997
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1186 - mae: 0.2700
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4426 - mae: 0.4021
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1617 - mae: 0.2586
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3485 - mae: 0.3266
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1378 - mae: 0.2864
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2770 - mae: 0.3041
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1240 - mae: 0.2626
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1448 - mae: 0.2639
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1885 - mae: 0.2936
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1265 - mae: 0.2377
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1705 - mae: 0.2581
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2095 - mae: 0.3016
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3965 - mae: 0.3011
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2393 - mae: 0.3716
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2263 - mae: 0.2827
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1825 - mae: 0.2683
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1492 - mae: 0.2543
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1338 - mae: 0.2069
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2138 - mae: 0.2981
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1591 - mae: 0.2372
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1656 - mae: 0.2638
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1163 - mae: 0.2297
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1282 - mae: 0.2256
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2442 - mae: 0.3007
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2875 - mae: 0.2868
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1067 - mae: 0.2203
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1965 - mae: 0.2853
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3519 - mae: 0.3545
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1943 - mae: 0.3051
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1514 - mae: 0.2340
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2669 - mae: 0.3185
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1857 - mae: 0.2954
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2335 - mae: 0.3360
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2364 - mae: 0.3221
# Epoch 73/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1203 - mae: 0.2503
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1999 - mae: 0.2808
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1097 - mae: 0.2508
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1377 - mae: 0.2546
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2832 - mae: 0.3181
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4176 - mae: 0.3533
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0926 - mae: 0.1987
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2363 - mae: 0.3008
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2407 - mae: 0.3183
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1045 - mae: 0.2321
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2438 - mae: 0.3109
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1427 - mae: 0.2416
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1954 - mae: 0.3056
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1458 - mae: 0.2217
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0661 - mae: 0.1702
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2423 - mae: 0.2925
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2813 - mae: 0.3044
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0921 - mae: 0.2057
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1560 - mae: 0.2317
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2383 - mae: 0.2615
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1659 - mae: 0.2399
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1136 - mae: 0.2160
# Epoch 95/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1646 - mae: 0.2157
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1811 - mae: 0.2979
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3560 - mae: 0.3077
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0986 - mae: 0.2401
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1630 - mae: 0.2449
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0835 - mae: 0.2017
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f478573bcb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5543 - mae: 0.4552
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8054 - mae: 0.6616
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.2320 - mae: 0.7578
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0770 - mae: 0.6954
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6840 - mae: 0.5570
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.2416 - mae: 0.7224
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7894 - mae: 0.6335
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6478 - mae: 0.5187
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6421 - mae: 0.5862
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4666 - mae: 0.5044
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7483 - mae: 0.6200
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5163 - mae: 0.4738
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4515 - mae: 0.5287
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7485 - mae: 0.5534
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3721 - mae: 0.4224
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4145 - mae: 0.3931
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3105 - mae: 0.4191
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5891 - mae: 0.5011
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4819 - mae: 0.4683
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4166 - mae: 0.4287
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5515 - mae: 0.4984
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2707 - mae: 0.3836
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6539 - mae: 0.4380
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4912 - mae: 0.4611
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5078 - mae: 0.4262
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3395 - mae: 0.4056
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3639 - mae: 0.3626
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3412 - mae: 0.3430
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5565 - mae: 0.4857
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5553 - mae: 0.4539
# Epoch 30/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5876 - mae: 0.4405
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5974 - mae: 0.4252
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5393 - mae: 0.4547
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3408 - mae: 0.4050
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5045 - mae: 0.4377
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1549 - mae: 0.3071
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8436 - mae: 0.5511
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6544 - mae: 0.4650
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2487 - mae: 0.3474
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3483 - mae: 0.3645
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4504 - mae: 0.4067
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4232 - mae: 0.3713
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2243 - mae: 0.3434
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2218 - mae: 0.3093
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3544 - mae: 0.3694
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2837 - mae: 0.3192
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1786 - mae: 0.3055
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3575 - mae: 0.3210
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7593 - mae: 0.4495
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2258 - mae: 0.3195
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3131 - mae: 0.3817
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3041 - mae: 0.3367
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2052 - mae: 0.2968
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6621 - mae: 0.4180
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7039 - mae: 0.5089
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3790 - mae: 0.4304
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2819 - mae: 0.3723
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8367 - mae: 0.5196
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2559 - mae: 0.3061
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2409 - mae: 0.3575
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4310 - mae: 0.3624
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5136 - mae: 0.4185
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2899 - mae: 0.3357
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1314 - mae: 0.2561
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3846 - mae: 0.4105
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4958 - mae: 0.4047
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4091 - mae: 0.3707
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4192 - mae: 0.4284
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3654 - mae: 0.3487
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3385 - mae: 0.3536
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2523 - mae: 0.3078
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7587 - mae: 0.4778
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2786 - mae: 0.2994
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3175 - mae: 0.3463
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2088 - mae: 0.3166
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2138 - mae: 0.3394
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4309 - mae: 0.3932
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2100 - mae: 0.2977
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4329 - mae: 0.3810
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1752 - mae: 0.2835
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3031 - mae: 0.3430
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3816 - mae: 0.3415
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3253 - mae: 0.3309
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2183 - mae: 0.2858
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2356 - mae: 0.3109
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3632 - mae: 0.4129
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3214 - mae: 0.3226
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3113 - mae: 0.3366
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3039 - mae: 0.3579
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2722 - mae: 0.2942
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4090 - mae: 0.3891
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3013 - mae: 0.3568
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5873 - mae: 0.4373
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3123 - mae: 0.3171
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8040 - mae: 0.4528
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2327 - mae: 0.3069
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2971 - mae: 0.3836
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1895 - mae: 0.3304
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2254 - mae: 0.2961
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6248 - mae: 0.4685
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2545 - mae: 0.3100
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4787a707a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4456 - mae: 0.3964
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.2060 - mae: 0.8225
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7384 - mae: 0.6971
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8121 - mae: 0.6382
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8572 - mae: 0.6065
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5198 - mae: 0.4601
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4604 - mae: 0.4357
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7213 - mae: 0.5920
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5721 - mae: 0.4907
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6511 - mae: 0.5068
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5015 - mae: 0.4744
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4327 - mae: 0.4297
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4109 - mae: 0.3802
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4869 - mae: 0.4369
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4033 - mae: 0.4038
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3599 - mae: 0.4052
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4124 - mae: 0.4234
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4257 - mae: 0.3709
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4409 - mae: 0.3941
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3522 - mae: 0.3648
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4637 - mae: 0.4317
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5229 - mae: 0.4453
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4872 - mae: 0.4253
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3503 - mae: 0.3820
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2178 - mae: 0.3038
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3012 - mae: 0.3512
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5432 - mae: 0.4501
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4622 - mae: 0.3780
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4043 - mae: 0.3883
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4937 - mae: 0.4328
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2553 - mae: 0.3385
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5342 - mae: 0.4273
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5102 - mae: 0.4444
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3579 - mae: 0.3619
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3599 - mae: 0.3554
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2810 - mae: 0.3259
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3239 - mae: 0.3816
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3850 - mae: 0.4098
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3783 - mae: 0.3748
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3410 - mae: 0.3474
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3206 - mae: 0.3479
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3366 - mae: 0.3006
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7713 - mae: 0.4680
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2693 - mae: 0.2896
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2684 - mae: 0.3283
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4266 - mae: 0.3985
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3795 - mae: 0.3864
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2788 - mae: 0.3020
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2082 - mae: 0.2643
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5822 - mae: 0.4357
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3216 - mae: 0.3735
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3086 - mae: 0.3549
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5490 - mae: 0.4089
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6590 - mae: 0.4861
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2059 - mae: 0.3163
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4655 - mae: 0.3366
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6947 - mae: 0.4266
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6146 - mae: 0.4894
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3527 - mae: 0.3352
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4451 - mae: 0.4036
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3653 - mae: 0.3885
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3439 - mae: 0.3194
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2526 - mae: 0.3704
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2737 - mae: 0.3170
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3655 - mae: 0.4117
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1813 - mae: 0.2780
# Epoch 66/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2913 - mae: 0.3782
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4400 - mae: 0.3881
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3592 - mae: 0.3892
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3370 - mae: 0.3300
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4515 - mae: 0.3732
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2055 - mae: 0.3009
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6523 - mae: 0.4683
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3714 - mae: 0.3764
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2593 - mae: 0.3309
# Epoch 75/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4742 - mae: 0.4602
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1927 - mae: 0.3046
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5696 - mae: 0.4480
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2547 - mae: 0.2961
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2609 - mae: 0.3112
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1779 - mae: 0.2661
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2508 - mae: 0.3218
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2107 - mae: 0.2689
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2844 - mae: 0.3041
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5339 - mae: 0.4256
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7900 - mae: 0.4953
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1553 - mae: 0.2453
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2793 - mae: 0.3364
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5121 - mae: 0.3557
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4976 - mae: 0.3907
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4605 - mae: 0.4518
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4092 - mae: 0.3667
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2646 - mae: 0.3042
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4338 - mae: 0.3287
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1710 - mae: 0.2714
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3459 - mae: 0.3795
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2259 - mae: 0.2565
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4635 - mae: 0.3736
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1738 - mae: 0.2863
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2633 - mae: 0.3479
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3049 - mae: 0.3291
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f478c5a6830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1587 - mae: 0.2823

# %%
#Scores
#here we will see MAE (mean absolute Error) scores of all model which we have saved in the list during each training in above section

all_scores_relu
# Out:
# [0.3239026367664337,
#  0.35847175121307373,
#  0.3857015371322632,
#  0.3493605852127075]

# %%
all_scores_tanh
# Out:
# [0.377968966960907,
#  0.31675994396209717,
#  0.4129483997821808,
#  0.33884844183921814]

# %%
all_scores_regular
# Out:
# [0.3818645775318146,
#  0.22656527161598206,
#  0.47483351826667786,
#  0.421843022108078]

# %%
all_scores_drop
# Out:
# [0.450240820646286,
#  0.4552305340766907,
#  0.3964078426361084,
#  0.28229400515556335]

# %%
# training on the training data
# here we will call each model separately from Models section and train on the training data and evaluate on the test data

model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f47879a0050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1106 - mae: 0.2562

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f478771d050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0777 - mae: 0.2122

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f47879efb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1036 - mae: 0.2060

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f47879fb050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1192 - mae: 0.2336

# %% [markdown]
# # Prediction Section
# ## here we will predict our prices of our test dataset with each model which we have trained in training section
# ## Note that here we will use the reverse process of Normalization to retrieve our values of price in thousand of dollars i.e. x = (y - mean)/ std ==>> we will calculate( y = x * std + mean) and then we will compare it with our target values

# %%
#Prediction Section
#here we will predict our prices of our test dataset with each model which we have trained in training section
#Note that here we will use the reverse process of Normalization to retrieve our values of price in thousand of dollars i.e. x = (y - mean)/ std ==>> we will calculate( y = x * std + mean) and then we will compare it with our target values

test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[21311.06]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[22045.04]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[23793.672]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20644.174]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f478783ae60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f47894bbc20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4787899e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f478c481dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
